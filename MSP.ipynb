# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
data = pd.read_excel("MSP.xlsx",index_col=0)

# %%
data.head()
# Out:
#                    2005-01-01  2006-01-01  2007-01-01  2008-01-01  2009-01-01  \
# Commodity
# NIGERSEED                 830        1130        1640        2005        2450
# JOWAR                     400         590         710         825         900
# COTTON                   1910        2010        2460        2830        3000
# DE-HUSKED COCONUT         950        1005        1100        1190        1200
# MOONG                    1280        1930        2370        2845        3170
#
#                    2010-01-01  2011-01-01  2012-01-01 2013-01-01  2014-01-01  \
# Commodity
# NIGERSEED                2900        3500        3500       3600        3650
# JOWAR                    1000        1520        1520       1550        1590
# COTTON                   3300        3900        4000       4050        4100
# DE-HUSKED COCONUT        1200        1400        1425       1425        1500
# MOONG                    3500        4400        4500       4600        4850
#
# ...

# %%
data=data.astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, NIGERSEED to Tur (Arhar)
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   2005-01-01 00:00:00  12 non-null     float64
#  1   2006-01-01 00:00:00  12 non-null     float64
#  2   2007-01-01 00:00:00  12 non-null     float64
#  3   2008-01-01 00:00:00  12 non-null     float64
#  4   2009-01-01 00:00:00  12 non-null     float64
#  5   2010-01-01 00:00:00  12 non-null     float64
#  6   2011-01-01 00:00:00  12 non-null     float64
#  7   2012-01-01 00:00:00  12 non-null     float64
#  8   2013-01-01 00:00:00  12 non-null     float64
#  9   2014-01-01 00:00:00  12 non-null     float64
#  10  2015-01-01 00:00:00  12 non-null     float64
#  11  2016-01-01 00:00:00  12 non-null     float64
#  12  2017-01-01 00:00:00  12 non-null     float64
#  13  2018-01-01 00:00:00  12 non-null     float64
# ...

# %%
data = data.transpose()

# %%
data
# Out:
# Commodity   NIGERSEED   JOWAR  COTTON  DE-HUSKED COCONUT   MOONG   BAJRA  \
# 2005-01-01      830.0   400.0  1910.0              950.0  1280.0   595.0
# 2006-01-01     1130.0   590.0  2010.0             1005.0  1930.0   655.0
# 2007-01-01     1640.0   710.0  2460.0             1100.0  2370.0   715.0
# 2008-01-01     2005.0   825.0  2830.0             1190.0  2845.0   790.0
# 2009-01-01     2450.0   900.0  3000.0             1200.0  3170.0   880.0
# 2010-01-01     2900.0  1000.0  3300.0             1200.0  3500.0   980.0
# 2011-01-01     3500.0  1520.0  3900.0             1400.0  4400.0  1175.0
# 2012-01-01     3500.0  1520.0  4000.0             1425.0  4500.0  1250.0
# 2013-01-01     3600.0  1550.0  4050.0             1425.0  4600.0  1250.0
# 2014-01-01     3650.0  1590.0  4100.0             1500.0  4850.0  1275.0
# 2015-01-01     3825.0  1650.0  4160.0             1600.0  5225.0  1330.0
# 2016-01-01     4050.0  1725.0  4320.0             1760.0  5575.0  1425.0
# ...

# %%
data.index
# Out:
# DatetimeIndex(['2005-01-01', '2006-01-01', '2007-01-01', '2008-01-01',
#                '2009-01-01', '2010-01-01', '2011-01-01', '2012-01-01',
#                '2013-01-01', '2014-01-01', '2015-01-01', '2016-01-01',
#                '2017-01-01', '2018-01-01', '2019-01-01', '2020-01-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
data.index = pd.to_datetime(data.index)

# %%
data
# Out:
# Commodity   NIGERSEED   JOWAR  COTTON  DE-HUSKED COCONUT   MOONG   BAJRA  \
# 2005-01-01      830.0   400.0  1910.0              950.0  1280.0   595.0
# 2006-01-01     1130.0   590.0  2010.0             1005.0  1930.0   655.0
# 2007-01-01     1640.0   710.0  2460.0             1100.0  2370.0   715.0
# 2008-01-01     2005.0   825.0  2830.0             1190.0  2845.0   790.0
# 2009-01-01     2450.0   900.0  3000.0             1200.0  3170.0   880.0
# 2010-01-01     2900.0  1000.0  3300.0             1200.0  3500.0   980.0
# 2011-01-01     3500.0  1520.0  3900.0             1400.0  4400.0  1175.0
# 2012-01-01     3500.0  1520.0  4000.0             1425.0  4500.0  1250.0
# 2013-01-01     3600.0  1550.0  4050.0             1425.0  4600.0  1250.0
# 2014-01-01     3650.0  1590.0  4100.0             1500.0  4850.0  1275.0
# 2015-01-01     3825.0  1650.0  4160.0             1600.0  5225.0  1330.0
# 2016-01-01     4050.0  1725.0  4320.0             1760.0  5575.0  1425.0
# ...

# %%
data.head()
# Out:
# Commodity   NIGERSEED  JOWAR  COTTON  DE-HUSKED COCONUT   MOONG  BAJRA  \
# 2005-01-01      830.0  400.0  1910.0              950.0  1280.0  595.0
# 2006-01-01     1130.0  590.0  2010.0             1005.0  1930.0  655.0
# 2007-01-01     1640.0  710.0  2460.0             1100.0  2370.0  715.0
# 2008-01-01     2005.0  825.0  2830.0             1190.0  2845.0  790.0
# 2009-01-01     2450.0  900.0  3000.0             1200.0  3170.0  880.0
#
# Commodity    PADDY    JUTE   WHEAT  SESAMUM  SUNFLOWER SEED  Tur (Arhar)
# 2005-01-01   615.0  1095.0   685.0     20.0           455.0       1860.0
# 2006-01-01   730.0  1225.0   790.0    300.0           960.0       1920.0
# 2007-01-01   865.0  1390.0   945.0   1000.0          1245.0       2250.0
# 2008-01-01   950.0  1440.0  1005.0   1800.0          1860.0       2780.0
# 2009-01-01  1030.0  1575.0  1120.0   2900.0          2350.0       3000.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16 entries, 2005-01-01 to 2020-01-01
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NIGERSEED          16 non-null     float64
#  1   JOWAR              16 non-null     float64
#  2   COTTON             16 non-null     float64
#  3   DE-HUSKED COCONUT  16 non-null     float64
#  4   MOONG              16 non-null     float64
#  5   BAJRA              16 non-null     float64
#  6   PADDY              16 non-null     float64
#  7   JUTE               16 non-null     float64
#  8   WHEAT              16 non-null     float64
#  9   SESAMUM            16 non-null     float64
#  10  SUNFLOWER SEED     16 non-null     float64
#  11  Tur (Arhar)        16 non-null     float64
# dtypes: float64(12)
# memory usage: 2.2 KB

# %%
data = data.iloc[:,:].astype(float, errors = 'raise')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16 entries, 2005-01-01 to 2020-01-01
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NIGERSEED          16 non-null     float64
#  1   JOWAR              16 non-null     float64
#  2   COTTON             16 non-null     float64
#  3   DE-HUSKED COCONUT  16 non-null     float64
#  4   MOONG              16 non-null     float64
#  5   BAJRA              16 non-null     float64
#  6   PADDY              16 non-null     float64
#  7   JUTE               16 non-null     float64
#  8   WHEAT              16 non-null     float64
#  9   SESAMUM            16 non-null     float64
#  10  SUNFLOWER SEED     16 non-null     float64
#  11  Tur (Arhar)        16 non-null     float64
# dtypes: float64(12)
# memory usage: 2.2 KB

# %%
data
# Out:
# Commodity   NIGERSEED   JOWAR  COTTON  DE-HUSKED COCONUT   MOONG   BAJRA  \
# 2005-01-01      830.0   400.0  1910.0              950.0  1280.0   595.0
# 2006-01-01     1130.0   590.0  2010.0             1005.0  1930.0   655.0
# 2007-01-01     1640.0   710.0  2460.0             1100.0  2370.0   715.0
# 2008-01-01     2005.0   825.0  2830.0             1190.0  2845.0   790.0
# 2009-01-01     2450.0   900.0  3000.0             1200.0  3170.0   880.0
# 2010-01-01     2900.0  1000.0  3300.0             1200.0  3500.0   980.0
# 2011-01-01     3500.0  1520.0  3900.0             1400.0  4400.0  1175.0
# 2012-01-01     3500.0  1520.0  4000.0             1425.0  4500.0  1250.0
# 2013-01-01     3600.0  1550.0  4050.0             1425.0  4600.0  1250.0
# 2014-01-01     3650.0  1590.0  4100.0             1500.0  4850.0  1275.0
# 2015-01-01     3825.0  1650.0  4160.0             1600.0  5225.0  1330.0
# 2016-01-01     4050.0  1725.0  4320.0             1760.0  5575.0  1425.0
# ...

# %%
train = data.iloc[0:15, 0]
test = data.iloc[15:, 0]

# %%
train
# Out:
# 2005-01-01     830.0
# 2006-01-01    1130.0
# 2007-01-01    1640.0
# 2008-01-01    2005.0
# 2009-01-01    2450.0
# 2010-01-01    2900.0
# 2011-01-01    3500.0
# 2012-01-01    3500.0
# 2013-01-01    3600.0
# 2014-01-01    3650.0
# 2015-01-01    3825.0
# 2016-01-01    4050.0
# 2017-01-01    5877.0
# 2018-01-01    5940.0
# 2019-01-01    6695.0
# Name: NIGERSEED, dtype: float64

# %%
test
# Out:
# 2020-01-01    6930.0
# Name: NIGERSEED, dtype: float64

# %%
data.head()
# Out:
# Commodity   NIGERSEED  JOWAR  COTTON  DE-HUSKED COCONUT   MOONG  BAJRA  \
# 2005-01-01      830.0  400.0  1910.0              950.0  1280.0  595.0
# 2006-01-01     1130.0  590.0  2010.0             1005.0  1930.0  655.0
# 2007-01-01     1640.0  710.0  2460.0             1100.0  2370.0  715.0
# 2008-01-01     2005.0  825.0  2830.0             1190.0  2845.0  790.0
# 2009-01-01     2450.0  900.0  3000.0             1200.0  3170.0  880.0
#
# Commodity    PADDY    JUTE   WHEAT  SESAMUM  SUNFLOWER SEED  Tur (Arhar)
# 2005-01-01   615.0  1095.0   685.0     20.0           455.0       1860.0
# 2006-01-01   730.0  1225.0   790.0    300.0           960.0       1920.0
# 2007-01-01   865.0  1390.0   945.0   1000.0          1245.0       2250.0
# 2008-01-01   950.0  1440.0  1005.0   1800.0          1860.0       2780.0
# 2009-01-01  1030.0  1575.0  1120.0   2900.0          2350.0       3000.0

# %%
#!pip install pmdarima

# %%
from pmdarima.arima import auto_arima
stepwise_model = auto_arima(data.iloc[0:15, 0], start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=27.405, Time=0.17 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=29.616, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=inf, Time=0.15 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.07 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=25.400, Time=0.09 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=27.395, Time=0.22 sec
#  ARIMA(1,1,1)(1,1,1)[12]             : AIC=inf, Time=0.33 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=30.189, Time=0.02 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=inf, Time=0.04 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,1,2)(0,1,0)[12]             : AIC=27.392, Time=0.12 sec
#  ARIMA(0,1,2)(0,1,0)[12]             : AIC=inf, Time=0.04 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=inf, Time=0.08 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=inf, Time=0.14 sec
# ...

# %%
train
# Out:
# 2005-01-01     830.0
# 2006-01-01    1130.0
# 2007-01-01    1640.0
# 2008-01-01    2005.0
# 2009-01-01    2450.0
# 2010-01-01    2900.0
# 2011-01-01    3500.0
# 2012-01-01    3500.0
# 2013-01-01    3600.0
# 2014-01-01    3650.0
# 2015-01-01    3825.0
# 2016-01-01    4050.0
# 2017-01-01    5877.0
# 2018-01-01    5940.0
# 2019-01-01    6695.0
# Name: NIGERSEED, dtype: float64

# %%
data
# Out:
# Commodity   NIGERSEED   JOWAR  COTTON  DE-HUSKED COCONUT   MOONG   BAJRA  \
# 2005-01-01      830.0   400.0  1910.0              950.0  1280.0   595.0
# 2006-01-01     1130.0   590.0  2010.0             1005.0  1930.0   655.0
# 2007-01-01     1640.0   710.0  2460.0             1100.0  2370.0   715.0
# 2008-01-01     2005.0   825.0  2830.0             1190.0  2845.0   790.0
# 2009-01-01     2450.0   900.0  3000.0             1200.0  3170.0   880.0
# 2010-01-01     2900.0  1000.0  3300.0             1200.0  3500.0   980.0
# 2011-01-01     3500.0  1520.0  3900.0             1400.0  4400.0  1175.0
# 2012-01-01     3500.0  1520.0  4000.0             1425.0  4500.0  1250.0
# 2013-01-01     3600.0  1550.0  4050.0             1425.0  4600.0  1250.0
# 2014-01-01     3650.0  1590.0  4100.0             1500.0  4850.0  1275.0
# 2015-01-01     3825.0  1650.0  4160.0             1600.0  5225.0  1330.0
# 2016-01-01     4050.0  1725.0  4320.0             1760.0  5575.0  1425.0
# ...

# %%
stepwise_model.fit(train)
# Out:
# ARIMA(order=(1, 1, 1), scoring_args={}, seasonal_order=(0, 1, 0, 12),
#       suppress_warnings=True)

# %%
future_forecast = stepwise_model.predict(n_periods=1)

# %%
future_forecast
# Out:
# array([6823.00422873])

# %%
future_forecast = pd.DataFrame(future_forecast,index = test.index,columns=['Prediction of MSP_1'])
future_forecast.head()
# Out:
#             Prediction of MSP_1
# 2020-01-01          6823.004229

# %%
test.head()
# Out:
# 2020-01-01    6930.0
# Name: NIGERSEED, dtype: float64

# %%
pd.concat([train,future_forecast],axis=1).plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import r2_score
r2_score(test,future_forecast)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:796: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# nan
